# %%
import numpy as np

# %%
v1=np.array([1,2]).reshape(2,1)
v2=np.array([[1],[2]])
print(v1.T,"\n\n",v2)
# Out:
# [[1 2]]
#
#  [[1]
#  [2]]

# %%
v1.transpose(1,0)
# Out:
# array([[1, 2]])

# %%
a=np.array([1,2])
b=np.array([1,2])
a+b
# Out:
# array([2, 4])

# %%
a.dot(b),(1*1+1*4)
# Out:
# (5, 5)

# %%
np.linalg.norm(a)
# Out:
# 19.621416870348583

# %%
import datetime
a=np.arange(1,1001)
b=np.ones(1000)
k=0
ftime= datetime.datetime.now()
for i in range(len(a)):
    k+=a[i]*b[i]
print(k)
etime= datetime.datetime.now()
print(etime-ftime)
# Out:
# 500500.0
# 0:00:00.001994

# %%
ftime= datetime.datetime.now()
print(a.dot(b))

etime= datetime.datetime.now()
print(etime-ftime)
# Out:
# 500500.0
# 0:00:00

# %%
import matplotlib.pyplot as plt

# %%
def f(w0,w1):       # f 함수 정의
    return w0**2+2*w0*w1+3  
def df_dw0(w0,w1):  # f의 w0에 대한 편미분
    return 2*w0+2*w1   
def df_dw1(w0,w1):  # f의 w1에 대한 편미분
    return 2*w0
w_range= 2
dw=0.25

w0= np.arange(-w_range,w_range+dw,dw)
w1= np.arange(-w_range,w_range+dw,dw)
wn=w0.shape[0]
ww0,ww1=np.meshgrid(w0,w1)
ff=np.zeros((len(w0),len(w1)))
dff_dw0=np.zeros((len(w0),len(w1)))
dff_dw1=np.zeros((len(w0),len(w1)))
for i0 in range(wn):
    for i1 in range(wn):
        ff[i1,i0]=f(w0[i0],w1[i1])
        dff_dw0[i1,i0]=df_dw0(w0[i0],w1[i1])
        dff_dw1[i1,i0]=df_dw1(w0[i0],w1[i1])

plt.figure(figsize=(9,4))       
plt.subplots_adjust(wspace=0.3)
plt.subplot(1,2,1)
cont=plt.contour(ww0,ww1,ff,10,colors='k') #f의 등고선 표시
cont.clabel(fmt="%2.0f",fontsize=8)
plt.xticks(range(-w_range,w_range + 1,1))
plt.yticks(range(-w_range,w_range + 1,1))
plt.xlim(-w_range-0.5,w_range +  .5)
plt.ylim(-w_range- .5,w_range +  .5)
plt.xlabel("$w_0$", fontsize=14) # $: 수직 글씨가 정자체로 이쁘게 나옴
plt.ylabel("$w_1$", fontsize=14)

plt.subplot(1,2,2)
plt.quiver(ww0,ww1,dff_dw0,dff_dw1) # 경사벡터 표시
plt.xlabel("$w_0$", fontsize=14)
plt.ylabel("$w_1$", fontsize=14)
plt.xticks(range(-w_range,w_range + 1,1))
plt.yticks(range(-w_range,w_range + 1,1))
plt.xlim(-w_range-0.5,w_range + .5)
plt.ylim(-w_range- .5,w_range + .5)
plt.show()

# %%
a=np.array([1,2,3])
b=a=np.array([4,5,6])
a.dot(b),a*b
# Out:
# (77, array([16, 25, 36]))

# %%
np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
a=np.array([[1,2],[3,4]])
np.linalg.inv(a)
# Out:
# array([[-2. ,  1. ],
#        [ 1.5, -0.5]])

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
x = np.linspace(-4,4,100)
y=2**x
y2=3**x
y3=0.5**x
y4=(1/3)**x
plt.figure(figsize=(5,5))
plt.plot(x,y,'black',linewidth=3,label='$y=2^x$')
plt.plot(x,y2,'cornflowerblue',linewidth=3,label='$y=3^x$')
plt.plot(x,y3,'gray',linewidth=3,label='$y=0.5^x$')
plt.plot(x,y4,'red',linewidth=3,label='$y=(1/3)^x$')

plt.ylim(-2,6)
plt.ylim(-4,4)
plt.grid(True)
plt.legend(loc='lower right')
plt.show()

# %%
x= np.linspace(-8,8,100)
y=x**2
x2= np.linspace(0.001,8,100)
y2=np.log(x2) / np.log(2)
plt.figure(figsize=(5,5))
plt.plot(x,y,'black',linewidth=3,label='$y=x^2$')
plt.plot(x2,y2,'cornflowerblue',linewidth=3,label='$y=log$')
plt.plot(x,x,'black',linestyle='--',linewidth=1)
plt.ylim(-8,8)
plt.xlim(-8,8)
plt.grid(True)
plt.legend(loc='lower right')

plt.show()

# %%
x= np.linspace(-4,4,100) # 시작, 끝, 100개로 나눔
y=(x-1)**2+2
logy=np.log(y)

plt.figure(figsize=(4,4))
plt.plot(x,y,'black',linewidth=3)
plt.plot(x, logy, 'cornflowerblue', linewidth=3)

plt.yticks(range(-4,9,1))
plt.xticks(range(-4,5,1))
plt.ylim(-4,8)
plt.xlim(-4,4)
plt.grid(True)
plt.show()

# %%
x=np.linspace(-10,10,100) # 시그모이드 - 활성화 함수, 계단함수
y=1 / (1+np.exp(-x))

plt.figure(figsize=(4,4))
plt.plot(x,y,'black',linewidth=3)
plt.ylim(-1,2)
plt.xlim(-10,10)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
def softmax(x0,x1,x2):
    u = np.exp(x0) + np.exp(x1) + np.exp(x2)
    return np.exp(x0)/u, np.exp(x1)/u, np.exp(x2)/u

y= softmax(2,1,-1)
print("y: {0}".format(np.round(y,2)))
print("y 합계: {0}".format(np.sum(y)))

from mpl_toolkits.mplot3d import Axes3D
xn=20
x0=np.linspace(-4,4,xn)
x1=np.linspace(-4,4,xn)

y= np.zeros((xn,xn,3))
for i0 in range(xn):
    for i1 in range(xn):
        y[i1,i0,:] = softmax(x0[i0],x1[i1],1)
xx0,xx1 = np.meshgrid(x0,x1)

plt.figure(figsize=(8,3))
for i in range(2):
    ax = plt.subplot(1,2,i+1,projection='3d')
    ax.plot_surface(xx0,xx1,y[:,:,i], rstride=1,cstride=1, alpha=0.3,color='blue',
    edgecolor='black')
    ax.set_xlabel('$x_0$',fontsize=14)
    ax.set_ylabel('$x_1$',fontsize=14)
    ax.view_init(40,-125)
plt.show()
# Out:
# y: [0.71 0.26 0.04]
# y 합계: 1.0

# %%
def gauss(mu,sigma,a):
    return a *np.exp(-(x-mu)**2 / sigma**2)

x = np.linspace(-4,8,100)
plt.figure(figsize=(4,4))
plt.plot(x,gauss(0,1,1),'black',linewidth=3, label='$(0,1,1)$'
 )
plt.plot(x,gauss(2,3,0.5),'gray',linewidth=3, label='$(2,3,0.5)$'  )
plt.ylim(-1,1.5)
plt.xlim(-4,8)
plt.grid(True)
plt.legend(loc='lower right')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline  
# gt5로 하면 따로 창이 뜸, inline은 주피터에 뜸

#가우스 함수
def gauss(x,mu,sigma):
    N,D = x.shape
    c1= 1 / (2*np.pi)**(D/2)
    c2= 1 / (np.linalg.det(sigma)**(1/2))
    inv_sigma = np.linalg.inv(sigma)
    c3=x-mu
    c4=np.dot(c3,inv_sigma)
    c5=np.zeros(N)
    for d in range(D):
        c5 = c5 + c4[:,d] * c3[:,d]
    p = c1*c2 * np.exp(-c5/2)
    return p
X_range0 = [-3,3]
X_range1 = [-3,3]
# 등고선 표시
def show_contour_gauss(mu,sig):
    xn = 40
    x0 = np.linspace(X_range0[0], X_range0[1],xn)
    x1 = np.linspace(X_range1[0], X_range1[1],xn)
    xx0,xx1=np.meshgrid(x0,x1)
    x = np.c_[np.reshape(xx0,xn*xn,1),np.reshape(xx1,xn*xn,1)]
    f= gauss(x,mu,sig)
    f= f.reshape(xn,xn)
    f = f.T
    cont = plt.contour(xx0,xx1,f,15,colors='k')
    plt.grid(True)
# 값 대입
x= np.array([[1,2],[2,1],[3,4]])
mu= np.array([1,2])
sigma = np.array([[1,0],[0,1]])
print(gauss(x,mu,sigma))
    
def show3d_gauss(ax,mu,sig):
    xn=40
    x0= np.linspace(X_range0[0],X_range0[1],xn)
    x1= np.linspace(X_range1[0],X_range1[1],xn)
    xx0,xx1=np.meshgrid(x0,x1)
    x = np.c_[np.reshape(xx0,xn*xn,1),np.reshape(xx1,xn*xn,1)]
    f= gauss(x,mu,sig)
    f= f.reshape(xn,xn)
    f = f.T
    ax.plot_surface(xx0,xx1,f,rstride=2,cstride=2,alpha=0.3,
                   color='blue',edgecolor = 'black')

    
    
#메인
mu = np.array([1,0.5])
sigma = np.array([[2,1],[1,1]])
Fig = plt.figure(1,figsize=(7,3))
Fig.add_subplot(1,2,1)
show_contour_gauss(mu,sigma)
plt.xlim(X_range0)
plt.ylim(X_range1)
plt.xlabel('$x_0$', fontsize= 14)
plt.ylabel('$x_1$', fontsize= 14)
Ax = Fig.add_subplot(1,2,2, projection='3d')
show3d_gauss(Ax,mu,sigma)
Ax.set_zticks([0.05,0.1])
Ax.set_xlabel('$x_0$',fontsize=14)
Ax.set_ylabel('$x_1$',fontsize=14)
Ax.view_init(-40,100)
plt.show()
# Out:
# [0.15915494 0.05854983 0.00291502]

# %%
def show3d_gauss(ax,mu,sig):
    xn=40
    x0= np.linspace(X_range0[0],X_range0[1],xn)
    x1= np.linspace(X_range1[0],X_range1[1],xn)
    xx0,xx1=np.meshgrid(x0,x1)
    x = np.c_[np.reshape(xx0,xn*xn,1),np.reshape(xx1,xn*xn,1)]
    f= gauss(x,mu,sig)
    f= f.reshape(xn,xn)
    f = f.T
    ax.plot_surface(xx0,xx1,f,rstride=2,cstride=2,alpha=0.3,
                   color='blue',edgecolor = 'black')

#메인
mu = np.array([1,0.5])
sigma = np.array([[2,1],[1,1]])
Fig = plt.figure(1,figsize=(7,3))
Fig.add_subplot(1,2,1)
show_contour_gauss(mu,sigma)
plt.xlim(X_range0)
plt.ylim(X_range1)
plt.xlabel('$x_0$', fontsize= 14)
plt.ylabel('$x_1$', fontsize= 14)
Ax = Fig.add_subplot(1,2,2, proiection='3d')
show3d_gauss(Ax,mu,sigma)
Ax.set_zticks([0.05,0.1])
Ax.set_xlabel('$x_0$',fontsize=14)
Ax.set_ylabel('$x_1$',fontsize=14)
Ax.view_init(40,-100)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-67fb6a5a2225> in <module>
#      16 Fig = plt.figure(1,figsize=(7,3))
#      17 Fig.add_subplot(1,2,1)
# ---> 18 show_contour_gauss(mu,sigma)
#      19 plt.xlim(X_range0)
#      20 plt.ylim(X_range1)
#
# NameError: name 'show_contour_gauss' is not defined
