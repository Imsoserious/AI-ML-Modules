# %%
#============================================================#
# 예제 8: 인물 이미지 변형을 위한 CycleGAN 구현
#============================================================#

"""
이 예제에서 사용하는 이미지 데이터는 DCGAN에서 사용한 인물 흑백 이미지 20장이다. 
20장 중 10장은 정상 이미지 x(도메인 A), 10장은 회전한 이미지로 변형하여 y(도메인 B)로 사용한다. 
도메인 A에 속하는 이미지를 입력하면 회전한 이미지로 변형하고, 도메인 B에 속하는 
회전한 이미지를 입력하면 정상 이미지로 변형하는 CycleGAN을 만드는 것이 목적이다. 
단, 도메인 A에 속하는 이미지를 회전한 이미지가 도메인 B에 존재한다고
확신할 수 없다는 사실에 주의한다.

생성자(G=G_AB, F=G_BA)와 판별자(D_A, D_B)는 입력층, 1개의 은닉층 및 출력층으로
구성된 전방향 신경망이다. 인물 이미지는 45*40 = 1800 픽셀의 이미지이므로 생성자의 출
력층은 1,800개의 출력노드를 가진다. 모든 출력노드에 적용되는 활성함수로 시그모이드 함
수를 사용하고 모든 가중치는 Xavier 초기치를 사용한다.
"""

# 필요한 라이브러리 불러들임 
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from PIL import Image as Im
import os
import glob  


# 그래프 리셋
tf.reset_default_graph() 
# 재현성을 위해 시드 지정
tf.set_random_seed(1)

#--------------------------------------------------
# data 불러오기
#--------------------------------------------------
 
#os.chdir('C:/Users/admin/Dropbox/저서/텐서플로_딥러닝/GANs_tensorflow/')
files=glob.glob('./face20/*.png')

img=[]          
for file in files:
    a=Im.open(file) 
    a=a.convert('L') # 흑백화면으로 
    a1=np.array(a)
    img.append(a1)        
    

xr=np.asarray(img)/255. # convert list to array

nr=np.prod(xr.shape[1:3]) # 45*40=1800
Xr=np.reshape(xr,[len(img),nr]) #=[20,1800]


import scipy.ndimage.interpolation
# Real image
X_rA = Xr[:10]
# Rotated image
X_rB = Xr[10:].reshape(-1, 45, 40)
X_rB = scipy.ndimage.interpolation.rotate(X_rB, 90, axes=(1, 2))
X_rB = X_rB.reshape(-1, 45*40)

# divide to train and test
XA=X_rA[0:2,:]
X_trainA=X_rA[2:10,:]
XB=X_rB[0:2,:]
X_trainB=X_rB[2:10,:]

# 훈련용과 시험용 이미지 개수와 입력 변수의 수
sample_size= X_trainA.shape[0] #8 
sample_size_test= XA.shape[0] #2 
X_dim = X_trainA.shape[1] #=1800
#-------------------------------------------
# 매개변수 설정
#-------------------------------------------
# 생성자의 두 은닉층 크기: 128
# 비판자의 두 은닉층 크기: 128
# 미니배치 크기: 20
# 반복 수: 300
# 학습률 : 0.001

learning_rate = 0.001
batch_size = 2
epochs =600 # no. of epochs
h_dim = 128

# 입력 이미지 placeholder
X_A = tf.placeholder(tf.float32, shape=[None, X_dim])
X_B = tf.placeholder(tf.float32, shape=[None, X_dim])


# 판별자의 가중치와 편의(# 사비에르 초기치 사용)
D_A_W1 = tf.get_variable('D_A_W1',shape=[X_dim, h_dim],initializer=tf.contrib.layers.xavier_initializer())
D_A_b1 = tf.Variable(tf.zeros([h_dim]))
D_A_W2 = tf.get_variable('D_A_W2', shape=[h_dim, 1],initializer=tf.contrib.layers.xavier_initializer())
D_A_b2 = tf.Variable(tf.zeros([1]))

D_B_W1 = tf.get_variable('D_B_W1', shape=[X_dim, h_dim],initializer=tf.contrib.layers.xavier_initializer())
D_B_b1 = tf.Variable(tf.zeros(shape=[h_dim]))
D_B_W2 = tf.get_variable('D_B_W2', shape=[h_dim, 1],initializer=tf.contrib.layers.xavier_initializer())
D_B_b2 = tf.Variable(tf.zeros([1]))

# 생성자의 가중치와 편의(# 사비에르 초기치 사용)
G_AB_W1 = tf.get_variable('D_AB_W1', shape=[X_dim, h_dim],initializer=tf.contrib.layers.xavier_initializer())
G_AB_b1 = tf.Variable(tf.zeros([h_dim]))
G_AB_W2 = tf.get_variable('D_AB_W2', shape=[h_dim, X_dim],initializer=tf.contrib.layers.xavier_initializer())
G_AB_b2 = tf.Variable(tf.zeros([X_dim]))

G_BA_W1 = tf.get_variable('D_BA_W1', shape=[X_dim, h_dim],initializer=tf.contrib.layers.xavier_initializer())
G_BA_b1 = tf.Variable(tf.zeros([h_dim]))
G_BA_W2 = tf.get_variable('D_BA_W2', shape=[h_dim, X_dim],initializer=tf.contrib.layers.xavier_initializer())
G_BA_b2 = tf.Variable(tf.zeros([X_dim]))


# 모수 모음
theta_DA = [D_A_W1, D_A_W2, D_A_b1, D_A_b2]
theta_DB= [ D_B_W1, D_B_W2, D_B_b1, D_B_b2]
theta_G = [G_AB_W1, G_AB_W2, G_AB_b1, G_AB_b2,
           G_BA_W1, G_BA_W2, G_BA_b1, G_BA_b2]

#------------------------------------------------
# 생성자 정의:
#------------------------------------------------
def G_AB(X):
    h1 = tf.nn.relu(tf.matmul(X, G_AB_W1) + G_AB_b1)
    return tf.nn.sigmoid(tf.matmul(h1, G_AB_W2) + G_AB_b2)


def G_BA(X):
    h1 = tf.nn.relu(tf.matmul(X, G_BA_W1) + G_BA_b1)
    return tf.nn.sigmoid(tf.matmul(h1, G_BA_W2) + G_BA_b2)

#------------------------------------------------
# 판별자 정의:
#------------------------------------------------
def D_A(X):
    h1 = tf.nn.relu(tf.matmul(X, D_A_W1) + D_A_b1)
    return tf.nn.sigmoid(tf.matmul(h1, D_A_W2) + D_A_b2)


def D_B(X):
    h1 = tf.nn.relu(tf.matmul(X, D_B_W1) + D_B_b1)
    return tf.nn.sigmoid(tf.matmul(h1, D_B_W2) + D_B_b2)



# 생성(변형)결과 
X_AB = G_AB(X_A)
X_BA = G_BA(X_B)


# 판별자 D_A 결과 
D_A_real = D_A(X_A)
D_A_fake = D_A(X_BA)

# 판별자 D_B 결과
D_B_real = D_B(X_B)
D_B_fake = D_B(X_AB)

# 복원( x -> G(x)-> F(G(x)-> x))
X_ABA = G_BA(X_AB)

# 복원( y -> F(x)-> G(F(x)-> y))
X_BAB = G_AB(X_BA)


# 판별자 비용함수 (LSGAN 적용)
DA_loss = 0.5 * (tf.reduce_mean((D_A_real - 1)**2)+ 0.5*tf.reduce_mean(D_A_fake**2))
DB_loss = 0.5 * (tf.reduce_mean((D_B_real - 1)**2)+ 0.5*tf.reduce_mean(D_B_fake**2))

# 생성자 비용함수
GAB_loss = 0.5 * tf.reduce_mean((D_A_fake - 1)**2)+0.5 * tf.reduce_mean((D_B_fake - 1)**2)

# 복원에 대한 비용함수
C_loss=tf.reduce_mean(tf.abs(X_A-X_ABA))+tf.reduce_mean(tf.abs(X_B-X_BAB))
G_loss=GAB_loss+C_loss


# Optimizer
DA_solver = tf.train.AdamOptimizer(learning_rate).minimize(DA_loss, var_list=theta_DA)
DB_solver = tf.train.AdamOptimizer(learning_rate).minimize(DB_loss, var_list=theta_DB)
G_solver = tf.train.AdamOptimizer(learning_rate).minimize(G_loss, var_list=theta_G)


#------------------------------------------------
# 텐서플로 그래프 생성 및 학습 
#------------------------------------------------
sess=tf.Session(); 
sess.run(tf.global_variables_initializer())
losses = []
for epoch in range(epochs):
    total_batch=int(sample_size/batch_size)
    avg_loss=0
    for ii in range(total_batch):
        if ii!=total_batch:
              XrA=X_trainA[ii*batch_size:(ii+1)*batch_size]
              XrB=X_trainB[ii*batch_size:(ii+1)*batch_size]
        else:
              XrA=X_trainA[(ii+1)*batch_size:]           
              XrB=X_trainB[(ii+1)*batch_size:]         
        DA_loss_curr,_ = sess.run([DA_loss,DA_solver], feed_dict={X_A: XrA, X_B: XrB})
        DB_loss_curr,_ = sess.run([DB_loss,DB_solver], feed_dict={X_A: XrA, X_B: XrB})
        G_loss_curr,_ = sess.run([G_loss,G_solver], feed_dict={X_A: XrA, X_B: XrB})    
        losss=DA_loss_curr+DB_loss_curr+G_loss_curr
        avg_loss+=losss/total_batch
    print('Epoch: %d' %(epoch+1),'DiscriminatorA Loss= %f,DiscriminatorB Loss= %f, Generator Loss= %f, Avg Loss=%f' %(DA_loss_curr, DB_loss_curr,G_loss_curr, avg_loss))   
    losses.append((DA_loss_curr, DB_loss_curr,G_loss_curr,avg_loss))
    # 100 에폭마다 변형되는 이미지 그림
    if (epoch+1)%100==0:  
        samples_A = sess.run(X_BA, feed_dict={X_B: XB})
        samples_B = sess.run(X_AB, feed_dict={X_A: XA})
        # 도메인  A의 test 이미지
        f,axes =plt.subplots(figsize=(7,7), nrows=1, ncols=2, sharey=True, sharex=True)
        for ii in range(2):
            plt.subplot(1,2,ii+1); plt.suptitle('Domain A') 
            plt.imshow(XA[ii].reshape(45,40),'Greys_r')
        # G_AB(X_A) 결과               
        f,axes =plt.subplots(figsize=(7,7), nrows=1, ncols=2, sharey=True, sharex=True)      
        for ii in range(2):
            plt.subplot(1,2,ii+1); plt.suptitle('Result of G_AB') 
            plt.imshow(samples_B[ii].reshape(40,45),'Greys_r')
        # 도메인  B의 test 이미지
        f,axes =plt.subplots(figsize=(7,7), nrows=1, ncols=2, sharey=True, sharex=True)
        f.suptitle(epoch+1)
        f.tight_layout()
        for ii in range(2):
            plt.subplot(1,2,ii+1);plt.suptitle('Domain B') 
            plt.imshow(XB[ii].reshape(40,45),'Greys_r')
        # G_BA(X_B) 결과          
        f,axes =plt.subplots(figsize=(7,7), nrows=1, ncols=2, sharey=True, sharex=True)     
        for ii in range(2):
            plt.subplot(1,2,ii+1);plt.suptitle('Result of G_BA') 
            plt.imshow(samples_A[ii].reshape(45,40),'Greys_r')  
                
        
# 판별자, 생성자의 비용함수 그림 
fig, ax = plt.subplots(figsize=(7,7))
losses = np.array(losses)
plt.plot(losses.T[0], label='DiscriminatorA')
plt.plot(losses.T[1], label='DiscriminatorB')
plt.plot(losses.T[2], label='Generator')
plt.title("Training Losses")
plt.legend()


# 도메인 A 에 속하는 이미지
f,axes =plt.subplots(figsize=(7,7), nrows=2, ncols=4, sharey=True, sharex=True)
f.tight_layout()
for ii in range(8):
    plt.subplot(2,4,ii+1); f.suptitle('Domain A')
    plt.imshow(X_trainA[ii].reshape(45,40),'Greys_r')

# 도메인 B 에 속하는 이미지    
f,axes =plt.subplots(figsize=(7,7), nrows=2, ncols=4, sharey=True, sharex=True)
for ii in range(8):
    plt.subplot(2,4,ii+1); f.suptitle('Domain B') 
    plt.imshow(X_trainB[ii].reshape(40,45),'Greys_r')
# Out:
# Epoch: 1 DiscriminatorA Loss= 0.249987,DiscriminatorB Loss= 0.232720, Generator Loss= 0.468305, Avg Loss=0.882529
# Epoch: 2 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.262391, Generator Loss= 0.417501, Avg Loss=0.901770
# Epoch: 3 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249856, Generator Loss= 0.381954, Avg Loss=0.835978
# Epoch: 4 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249988, Generator Loss= 0.353957, Avg Loss=0.799616
# Epoch: 5 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249994, Generator Loss= 0.341601, Avg Loss=0.770460
# Epoch: 6 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249996, Generator Loss= 0.336188, Avg Loss=0.756736
# Epoch: 7 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.322731, Avg Loss=0.749151
# Epoch: 8 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.310262, Avg Loss=0.743374
# Epoch: 9 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.307536, Avg Loss=0.738135
# Epoch: 10 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.306874, Avg Loss=0.734686
# Epoch: 11 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.306003, Avg Loss=0.732457
# Epoch: 12 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.302605, Avg Loss=0.730889
# Epoch: 13 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.302563, Avg Loss=0.729639
# Epoch: 14 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.300989, Avg Loss=0.728912
# Epoch: 15 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.302175, Avg Loss=0.727954
# Epoch: 16 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.299334, Avg Loss=0.727780
# Epoch: 17 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.301595, Avg Loss=0.727025
# Epoch: 18 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.298598, Avg Loss=0.727152
# Epoch: 19 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.300986, Avg Loss=0.726583
# Epoch: 20 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.297577, Avg Loss=0.726446
# Epoch: 21 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.299485, Avg Loss=0.726467
# Epoch: 22 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.297155, Avg Loss=0.725498
# Epoch: 23 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.296876, Avg Loss=0.725910
# Epoch: 24 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.297113, Avg Loss=0.724277
# Epoch: 25 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.295817, Avg Loss=0.724698
# Epoch: 26 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.295961, Avg Loss=0.723367
# Epoch: 27 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.295860, Avg Loss=0.723308
# Epoch: 28 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.294093, Avg Loss=0.723166
# Epoch: 29 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.296013, Avg Loss=0.721848
# Epoch: 30 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.292813, Avg Loss=0.722671
# Epoch: 31 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249998, Generator Loss= 0.296528, Avg Loss=0.721056
# Epoch: 32 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249998, Generator Loss= 0.290964, Avg Loss=0.722505
# Epoch: 33 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249997, Generator Loss= 0.298182, Avg Loss=0.720156
# Epoch: 34 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249997, Generator Loss= 0.288974, Avg Loss=0.723019
# Epoch: 35 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249995, Generator Loss= 0.298866, Avg Loss=0.720369
# Epoch: 36 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249995, Generator Loss= 0.287664, Avg Loss=0.723497
# Epoch: 37 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249988, Generator Loss= 0.295756, Avg Loss=0.722596
# Epoch: 38 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249981, Generator Loss= 0.286365, Avg Loss=0.723487
# Epoch: 39 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249930, Generator Loss= 0.288023, Avg Loss=0.724888
# Epoch: 40 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249658, Generator Loss= 0.288494, Avg Loss=0.719011
# Epoch: 41 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.247876, Generator Loss= 0.283604, Avg Loss=0.721421
# Epoch: 42 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.181657, Generator Loss= 0.562850, Avg Loss=0.763581
# Epoch: 43 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249201, Generator Loss= 0.282293, Avg Loss=0.749829
# Epoch: 44 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.249999, Generator Loss= 0.295630, Avg Loss=0.730641
# Epoch: 45 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.293196, Avg Loss=0.729081
# Epoch: 46 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.300244, Avg Loss=0.722271
# Epoch: 47 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.290898, Avg Loss=0.722592
# Epoch: 48 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.292242, Avg Loss=0.718023
# Epoch: 49 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.280935, Avg Loss=0.718824
# Epoch: 50 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.291370, Avg Loss=0.713395
# Epoch: 51 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.277005, Avg Loss=0.719362
# Epoch: 52 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.292047, Avg Loss=0.711317
# Epoch: 53 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.274086, Avg Loss=0.719993
# Epoch: 54 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.294124, Avg Loss=0.710297
# Epoch: 55 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.273782, Avg Loss=0.721757
# Epoch: 56 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.296018, Avg Loss=0.712279
# Epoch: 57 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.271880, Avg Loss=0.724709
# Epoch: 58 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.290258, Avg Loss=0.719347
# Epoch: 59 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.267990, Avg Loss=0.728825
# Epoch: 60 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.267355, Avg Loss=0.738959
# Epoch: 61 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.276207, Avg Loss=0.712935
# Epoch: 62 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.263291, Avg Loss=0.715353
# Epoch: 63 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.275182, Avg Loss=0.702800
# Epoch: 64 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.264995, Avg Loss=0.705424
# Epoch: 65 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.272557, Avg Loss=0.699943
# Epoch: 66 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.264870, Avg Loss=0.701446
# Epoch: 67 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.272625, Avg Loss=0.697104
# Epoch: 68 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.263875, Avg Loss=0.699093
# Epoch: 69 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.266384, Avg Loss=0.693678
# Epoch: 70 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.264889, Avg Loss=0.693940
# Epoch: 71 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.260185, Avg Loss=0.693535
# Epoch: 72 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.259910, Avg Loss=0.690399
# Epoch: 73 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.262404, Avg Loss=0.690275
# Epoch: 74 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.258424, Avg Loss=0.690303
# Epoch: 75 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.254504, Avg Loss=0.690440
# Epoch: 76 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.252755, Avg Loss=0.688121
# Epoch: 77 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.257916, Avg Loss=0.689054
# Epoch: 78 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.255403, Avg Loss=0.687314
# Epoch: 79 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.249406, Avg Loss=0.687540
# Epoch: 80 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.247098, Avg Loss=0.685945
# Epoch: 81 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.246781, Avg Loss=0.684717
# Epoch: 82 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.252901, Avg Loss=0.685894
# Epoch: 83 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.250111, Avg Loss=0.684556
# Epoch: 84 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.242595, Avg Loss=0.685541
# Epoch: 85 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.240691, Avg Loss=0.685339
# Epoch: 86 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.238681, Avg Loss=0.683731
# Epoch: 87 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.253850, Avg Loss=0.688564
# Epoch: 88 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.247160, Avg Loss=0.684220
# Epoch: 89 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.236008, Avg Loss=0.684011
# Epoch: 90 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.235747, Avg Loss=0.682291
# Epoch: 91 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.235469, Avg Loss=0.682025
# Epoch: 92 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.243700, Avg Loss=0.682819
# Epoch: 93 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.237335, Avg Loss=0.679908
# Epoch: 94 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.230594, Avg Loss=0.680939
# Epoch: 95 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.231514, Avg Loss=0.681629
# Epoch: 96 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.228415, Avg Loss=0.681154
# Epoch: 97 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.246805, Avg Loss=0.687492
# Epoch: 98 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.234363, Avg Loss=0.681151
# Epoch: 99 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.224906, Avg Loss=0.679452
# Epoch: 100 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.226766, Avg Loss=0.678269
# Epoch: 101 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.226573, Avg Loss=0.679209
# Epoch: 102 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.231830, Avg Loss=0.678286
# Epoch: 103 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.223065, Avg Loss=0.675314
# Epoch: 104 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.220267, Avg Loss=0.676155
# Epoch: 105 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.223372, Avg Loss=0.677593
# Epoch: 106 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.220534, Avg Loss=0.678129
# Epoch: 107 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.234423, Avg Loss=0.679966
# Epoch: 108 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.219808, Avg Loss=0.677828
# Epoch: 109 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.216241, Avg Loss=0.676500
# Epoch: 110 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.220171, Avg Loss=0.677730
# Epoch: 111 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.231921, Avg Loss=0.683964
# Epoch: 112 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.215388, Avg Loss=0.676913
# Epoch: 113 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.215371, Avg Loss=0.676561
# Epoch: 114 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.211781, Avg Loss=0.675564
# Epoch: 115 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.226586, Avg Loss=0.678691
# Epoch: 116 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.207823, Avg Loss=0.673702
# Epoch: 117 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.210376, Avg Loss=0.672161
# Epoch: 118 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.210470, Avg Loss=0.673052
# Epoch: 119 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.209321, Avg Loss=0.670176
# Epoch: 120 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.203097, Avg Loss=0.668316
# Epoch: 121 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.204151, Avg Loss=0.668836
# Epoch: 122 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.201293, Avg Loss=0.669195
# Epoch: 123 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.212874, Avg Loss=0.671597
# Epoch: 124 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.199880, Avg Loss=0.670249
# Epoch: 125 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.198539, Avg Loss=0.669194
# Epoch: 126 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.200857, Avg Loss=0.670426
# Epoch: 127 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.212255, Avg Loss=0.674849
# Epoch: 128 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.197402, Avg Loss=0.669190
# Epoch: 129 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.195155, Avg Loss=0.667195
# Epoch: 130 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.191960, Avg Loss=0.667585
# Epoch: 131 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.204994, Avg Loss=0.670991
# Epoch: 132 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.190145, Avg Loss=0.666547
# Epoch: 133 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.192144, Avg Loss=0.665672
# Epoch: 134 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.190944, Avg Loss=0.666156
# Epoch: 135 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.187737, Avg Loss=0.662807
# Epoch: 136 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.184511, Avg Loss=0.660651
# Epoch: 137 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.183605, Avg Loss=0.661452
# Epoch: 138 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.190799, Avg Loss=0.664463
# Epoch: 139 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.183227, Avg Loss=0.662176
# Epoch: 140 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.180341, Avg Loss=0.661740
# Epoch: 141 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.178632, Avg Loss=0.660025
# Epoch: 142 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.189554, Avg Loss=0.665377
# Epoch: 143 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.175160, Avg Loss=0.660803
# Epoch: 144 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.179130, Avg Loss=0.660246
# Epoch: 145 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.176751, Avg Loss=0.660359
# Epoch: 146 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.177296, Avg Loss=0.659502
# Epoch: 147 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.170592, Avg Loss=0.656749
# Epoch: 148 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.172109, Avg Loss=0.655529
# Epoch: 149 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.175464, Avg Loss=0.658211
# Epoch: 150 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.168921, Avg Loss=0.654406
# Epoch: 151 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.169124, Avg Loss=0.654027
# Epoch: 152 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.166271, Avg Loss=0.654244
# Epoch: 153 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.170861, Avg Loss=0.654922
# Epoch: 154 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.162498, Avg Loss=0.651966
# Epoch: 155 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.163926, Avg Loss=0.651531
# Epoch: 156 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.161738, Avg Loss=0.651146
# Epoch: 157 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.162296, Avg Loss=0.650007
# Epoch: 158 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.161914, Avg Loss=0.648677
# Epoch: 159 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.158387, Avg Loss=0.648448
# Epoch: 160 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.158569, Avg Loss=0.648946
# Epoch: 161 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.155844, Avg Loss=0.649305
# Epoch: 162 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.160293, Avg Loss=0.652118
# Epoch: 163 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.156883, Avg Loss=0.646488
# Epoch: 164 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.151399, Avg Loss=0.645508
# Epoch: 165 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.154813, Avg Loss=0.645346
# Epoch: 166 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.150731, Avg Loss=0.646751
# Epoch: 167 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.163837, Avg Loss=0.649012
# Epoch: 168 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.151640, Avg Loss=0.649385
# Epoch: 169 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.155011, Avg Loss=0.650822
# Epoch: 170 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.146786, Avg Loss=0.646693
# Epoch: 171 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.162799, Avg Loss=0.649337
# Epoch: 172 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.145205, Avg Loss=0.646177
# Epoch: 173 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.149204, Avg Loss=0.645162
# Epoch: 174 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.149458, Avg Loss=0.646007
# Epoch: 175 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.146868, Avg Loss=0.641578
# Epoch: 176 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.142100, Avg Loss=0.640539
# Epoch: 177 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.142155, Avg Loss=0.639656
# Epoch: 178 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.147559, Avg Loss=0.641733
# Epoch: 179 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.140014, Avg Loss=0.639055
# Epoch: 180 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.141108, Avg Loss=0.638197
# Epoch: 181 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.135981, Avg Loss=0.637976
# Epoch: 182 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.139779, Avg Loss=0.636947
# Epoch: 183 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.136661, Avg Loss=0.636665
# Epoch: 184 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.135053, Avg Loss=0.636011
# Epoch: 185 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.134950, Avg Loss=0.637286
# Epoch: 186 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.131373, Avg Loss=0.635859
# Epoch: 187 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.151141, Avg Loss=0.642855
# Epoch: 188 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.127344, Avg Loss=0.637332
# Epoch: 189 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.134907, Avg Loss=0.636883
# Epoch: 190 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.127529, Avg Loss=0.636098
# Epoch: 191 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.138003, Avg Loss=0.634200
# Epoch: 192 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.124934, Avg Loss=0.632861
# Epoch: 193 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.134001, Avg Loss=0.634951
# Epoch: 194 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.134118, Avg Loss=0.638625
# Epoch: 195 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.127769, Avg Loss=0.632113
# Epoch: 196 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.125220, Avg Loss=0.634018
# Epoch: 197 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.118673, Avg Loss=0.631366
# Epoch: 198 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.136730, Avg Loss=0.634720
# Epoch: 199 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.116504, Avg Loss=0.629092
# Epoch: 200 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.119442, Avg Loss=0.629002
# Epoch: 201 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.120381, Avg Loss=0.627381
# Epoch: 202 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.122107, Avg Loss=0.629593
# Epoch: 203 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.115433, Avg Loss=0.626801
# Epoch: 204 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.114451, Avg Loss=0.627836
# Epoch: 205 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.114842, Avg Loss=0.625154
# Epoch: 206 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.115712, Avg Loss=0.626979
# Epoch: 207 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.108200, Avg Loss=0.621794
# Epoch: 208 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.107296, Avg Loss=0.621081
# Epoch: 209 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.107309, Avg Loss=0.620389
# Epoch: 210 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.114496, Avg Loss=0.624084
# Epoch: 211 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.109962, Avg Loss=0.623535
# Epoch: 212 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.110643, Avg Loss=0.625052
# Epoch: 213 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.111190, Avg Loss=0.628701
# Epoch: 214 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.117770, Avg Loss=0.628660
# Epoch: 215 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.107608, Avg Loss=0.626171
# Epoch: 216 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.107541, Avg Loss=0.626031
# Epoch: 217 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.109425, Avg Loss=0.625267
# Epoch: 218 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.112881, Avg Loss=0.625519
# Epoch: 219 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.099772, Avg Loss=0.623457
# Epoch: 220 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.105913, Avg Loss=0.622716
# Epoch: 221 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.107334, Avg Loss=0.622131
# Epoch: 222 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.101377, Avg Loss=0.616475
# Epoch: 223 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.095687, Avg Loss=0.615518
# Epoch: 224 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.105777, Avg Loss=0.618163
# Epoch: 225 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.101973, Avg Loss=0.622104
# Epoch: 226 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.112640, Avg Loss=0.622193
# Epoch: 227 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.103962, Avg Loss=0.625653
# Epoch: 228 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.094796, Avg Loss=0.621834
# Epoch: 229 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.107629, Avg Loss=0.620202
# Epoch: 230 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.093457, Avg Loss=0.617704
# Epoch: 231 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.091969, Avg Loss=0.617989
# Epoch: 232 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.108584, Avg Loss=0.619653
# Epoch: 233 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.095281, Avg Loss=0.619918
# Epoch: 234 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.093890, Avg Loss=0.621975
# Epoch: 235 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.103026, Avg Loss=0.619721
# Epoch: 236 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.099499, Avg Loss=0.622038
# Epoch: 237 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.100535, Avg Loss=0.624339
# Epoch: 238 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.102058, Avg Loss=0.620293
# Epoch: 239 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.093456, Avg Loss=0.622486
# Epoch: 240 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.102637, Avg Loss=0.624010
# Epoch: 241 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.101521, Avg Loss=0.619612
# Epoch: 242 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.088419, Avg Loss=0.616721
# Epoch: 243 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.096727, Avg Loss=0.614563
# Epoch: 244 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.090357, Avg Loss=0.618294
# Epoch: 245 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.097415, Avg Loss=0.613696
# Epoch: 246 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.089034, Avg Loss=0.614090
# Epoch: 247 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.089396, Avg Loss=0.614445
# Epoch: 248 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.101272, Avg Loss=0.617412
# Epoch: 249 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.088879, Avg Loss=0.616634
# Epoch: 250 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.094681, Avg Loss=0.618134
# Epoch: 251 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.100614, Avg Loss=0.621361
# Epoch: 252 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.091971, Avg Loss=0.616387
# Epoch: 253 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.100838, Avg Loss=0.618779
# Epoch: 254 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.118164, Avg Loss=0.634033
# Epoch: 255 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.105395, Avg Loss=0.626720
# Epoch: 256 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.093838, Avg Loss=0.619518
# Epoch: 257 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.089139, Avg Loss=0.618501
# Epoch: 258 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.093763, Avg Loss=0.617618
# Epoch: 259 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.103853, Avg Loss=0.618410
# Epoch: 260 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.090350, Avg Loss=0.612335
# Epoch: 261 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.088286, Avg Loss=0.613928
# Epoch: 262 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.104259, Avg Loss=0.620676
# Epoch: 263 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.092583, Avg Loss=0.617784
# Epoch: 264 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.092256, Avg Loss=0.614168
# Epoch: 265 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.086714, Avg Loss=0.613681
# Epoch: 266 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.085864, Avg Loss=0.613305
# Epoch: 267 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.098447, Avg Loss=0.614198
# Epoch: 268 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.086063, Avg Loss=0.609049
# Epoch: 269 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.082601, Avg Loss=0.610640
# Epoch: 270 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.093404, Avg Loss=0.614469
# Epoch: 271 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.085281, Avg Loss=0.612411
# Epoch: 272 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.086389, Avg Loss=0.610427
# Epoch: 273 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.082536, Avg Loss=0.607468
# Epoch: 274 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.077000, Avg Loss=0.604931
# Epoch: 275 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.079541, Avg Loss=0.604162
# Epoch: 276 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.076246, Avg Loss=0.601037
# Epoch: 277 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.073549, Avg Loss=0.600672
# Epoch: 278 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.077663, Avg Loss=0.601073
# Epoch: 279 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.071846, Avg Loss=0.600680
# Epoch: 280 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.074754, Avg Loss=0.601050
# Epoch: 281 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.078102, Avg Loss=0.602699
# Epoch: 282 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.071011, Avg Loss=0.601500
# Epoch: 283 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.083874, Avg Loss=0.607351
# Epoch: 284 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.080944, Avg Loss=0.608243
# Epoch: 285 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.074445, Avg Loss=0.600626
# Epoch: 286 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.072683, Avg Loss=0.600199
# Epoch: 287 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.072810, Avg Loss=0.600364
# Epoch: 288 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.080133, Avg Loss=0.602778
# Epoch: 289 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.073559, Avg Loss=0.601480
# Epoch: 290 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.076822, Avg Loss=0.603324
# Epoch: 291 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.070803, Avg Loss=0.601432
# Epoch: 292 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.084572, Avg Loss=0.607337
# Epoch: 293 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.073027, Avg Loss=0.602544
# Epoch: 294 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.075933, Avg Loss=0.603227
# Epoch: 295 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.068918, Avg Loss=0.601316
# Epoch: 296 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.077584, Avg Loss=0.601208
# Epoch: 297 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.067269, Avg Loss=0.598694
# Epoch: 298 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.072448, Avg Loss=0.599000
# Epoch: 299 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.071837, Avg Loss=0.600816
# Epoch: 300 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.073634, Avg Loss=0.597480
# Epoch: 301 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.065754, Avg Loss=0.596095
# Epoch: 302 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.069053, Avg Loss=0.594395
# Epoch: 303 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.067802, Avg Loss=0.597528
# Epoch: 304 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.075418, Avg Loss=0.598477
# Epoch: 305 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.068241, Avg Loss=0.597737
# Epoch: 306 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.065502, Avg Loss=0.595472
# Epoch: 307 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.074848, Avg Loss=0.600093
# Epoch: 308 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.076585, Avg Loss=0.600535
# Epoch: 309 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.064304, Avg Loss=0.597239
# Epoch: 310 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.068567, Avg Loss=0.596013
# Epoch: 311 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.061823, Avg Loss=0.596484
# Epoch: 312 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.079031, Avg Loss=0.599508
# Epoch: 313 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.060569, Avg Loss=0.598168
# Epoch: 314 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.072608, Avg Loss=0.597939
# Epoch: 315 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.067535, Avg Loss=0.599139
# Epoch: 316 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.069988, Avg Loss=0.596845
# Epoch: 317 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.062512, Avg Loss=0.594437
# Epoch: 318 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.068418, Avg Loss=0.595096
# Epoch: 319 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.077606, Avg Loss=0.601788
# Epoch: 320 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.063703, Avg Loss=0.593874
# Epoch: 321 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.067029, Avg Loss=0.594436
# Epoch: 322 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.059281, Avg Loss=0.593837
# Epoch: 323 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.071819, Avg Loss=0.597808
# Epoch: 324 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.060458, Avg Loss=0.592335
# Epoch: 325 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.065626, Avg Loss=0.594465
# Epoch: 326 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.067640, Avg Loss=0.596939
# Epoch: 327 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.062784, Avg Loss=0.594835
# Epoch: 328 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.060041, Avg Loss=0.592485
# Epoch: 329 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.060937, Avg Loss=0.590734
# Epoch: 330 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.071647, Avg Loss=0.597116
# Epoch: 331 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.056702, Avg Loss=0.588392
# Epoch: 332 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.057825, Avg Loss=0.588026
# Epoch: 333 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.053417, Avg Loss=0.587503
# Epoch: 334 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.070040, Avg Loss=0.594271
# Epoch: 335 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.056344, Avg Loss=0.589420
# Epoch: 336 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.059540, Avg Loss=0.590865
# Epoch: 337 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.057996, Avg Loss=0.589970
# Epoch: 338 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.065163, Avg Loss=0.592039
# Epoch: 339 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.056680, Avg Loss=0.588495
# Epoch: 340 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.057928, Avg Loss=0.589378
# Epoch: 341 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.055041, Avg Loss=0.587962
# Epoch: 342 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.060413, Avg Loss=0.588439
# Epoch: 343 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.051920, Avg Loss=0.585891
# Epoch: 344 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.060951, Avg Loss=0.589786
# Epoch: 345 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.059000, Avg Loss=0.590387
# Epoch: 346 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.060241, Avg Loss=0.588633
# Epoch: 347 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.055820, Avg Loss=0.588767
# Epoch: 348 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.057899, Avg Loss=0.588311
# Epoch: 349 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.066605, Avg Loss=0.590862
# Epoch: 350 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.052435, Avg Loss=0.584022
# Epoch: 351 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.055758, Avg Loss=0.584836
# Epoch: 352 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.053771, Avg Loss=0.585580
# Epoch: 353 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.058801, Avg Loss=0.585972
# Epoch: 354 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.050999, Avg Loss=0.581135
# Epoch: 355 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.053921, Avg Loss=0.583126
# Epoch: 356 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.054994, Avg Loss=0.584389
# Epoch: 357 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.059216, Avg Loss=0.586060
# Epoch: 358 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.051923, Avg Loss=0.580775
# Epoch: 359 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.051303, Avg Loss=0.581020
# Epoch: 360 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.054687, Avg Loss=0.583337
# Epoch: 361 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.050691, Avg Loss=0.582028
# Epoch: 362 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.063398, Avg Loss=0.585049
# Epoch: 363 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.059233, Avg Loss=0.586481
# Epoch: 364 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.062808, Avg Loss=0.588671
# Epoch: 365 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.050336, Avg Loss=0.582780
# Epoch: 366 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.054021, Avg Loss=0.580571
# Epoch: 367 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.050964, Avg Loss=0.580455
# Epoch: 368 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.061066, Avg Loss=0.583291
# Epoch: 369 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.057559, Avg Loss=0.583872
# Epoch: 370 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.047869, Avg Loss=0.580852
# Epoch: 371 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.053072, Avg Loss=0.581335
# Epoch: 372 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.048225, Avg Loss=0.582151
# Epoch: 373 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.068315, Avg Loss=0.586766
# Epoch: 374 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.049779, Avg Loss=0.585830
# Epoch: 375 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.050895, Avg Loss=0.580332
# Epoch: 376 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.063889, Avg Loss=0.587176
# Epoch: 377 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.046724, Avg Loss=0.584678
# Epoch: 378 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.056157, Avg Loss=0.581261
# Epoch: 379 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.059629, Avg Loss=0.586147
# Epoch: 380 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.044198, Avg Loss=0.580882
# Epoch: 381 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.053884, Avg Loss=0.578961
# Epoch: 382 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.056723, Avg Loss=0.586055
# Epoch: 383 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.048659, Avg Loss=0.579242
# Epoch: 384 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.050313, Avg Loss=0.576806
# Epoch: 385 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.054336, Avg Loss=0.581423
# Epoch: 386 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.049090, Avg Loss=0.575257
# Epoch: 387 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.048397, Avg Loss=0.576783
# Epoch: 388 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.053588, Avg Loss=0.578312
# Epoch: 389 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.054071, Avg Loss=0.580774
# Epoch: 390 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.049615, Avg Loss=0.578029
# Epoch: 391 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.048605, Avg Loss=0.576410
# Epoch: 392 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.056074, Avg Loss=0.579686
# Epoch: 393 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.060877, Avg Loss=0.581509
# Epoch: 394 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.056235, Avg Loss=0.584108
# Epoch: 395 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.055724, Avg Loss=0.580698
# Epoch: 396 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.055882, Avg Loss=0.585300
# Epoch: 397 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.043951, Avg Loss=0.580904
# Epoch: 398 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.058066, Avg Loss=0.584304
# Epoch: 399 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.058674, Avg Loss=0.585116
# Epoch: 400 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.048366, Avg Loss=0.578928
# Epoch: 401 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.052275, Avg Loss=0.578538
# Epoch: 402 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.057221, Avg Loss=0.581178
# Epoch: 403 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.050511, Avg Loss=0.576669
# Epoch: 404 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.046763, Avg Loss=0.576599
# Epoch: 405 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.051715, Avg Loss=0.577307
# Epoch: 406 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.059511, Avg Loss=0.581086
# Epoch: 407 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.046259, Avg Loss=0.576855
# Epoch: 408 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.048486, Avg Loss=0.577290
# Epoch: 409 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.051518, Avg Loss=0.578599
# Epoch: 410 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.051915, Avg Loss=0.578101
# Epoch: 411 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.053488, Avg Loss=0.578419
# Epoch: 412 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.050922, Avg Loss=0.579030
# Epoch: 413 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.052913, Avg Loss=0.575345
# Epoch: 414 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.053084, Avg Loss=0.578016
# ...
# Epoch: 485 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.038750, Avg Loss=0.560103
# Epoch: 486 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.040170, Avg Loss=0.561078
# Epoch: 487 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.052670, Avg Loss=0.564966
# Epoch: 488 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.043507, Avg Loss=0.564721
# Epoch: 489 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.037501, Avg Loss=0.561608
# Epoch: 490 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.052527, Avg Loss=0.566220
# Epoch: 491 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.042584, Avg Loss=0.565053
# Epoch: 492 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.040165, Avg Loss=0.559626
# Epoch: 493 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.039495, Avg Loss=0.562167
# Epoch: 494 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.043897, Avg Loss=0.562266
# Epoch: 495 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.047514, Avg Loss=0.566842
# Epoch: 496 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.042025, Avg Loss=0.564594
# Epoch: 497 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.045229, Avg Loss=0.563939
# Epoch: 498 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.035800, Avg Loss=0.559021
# Epoch: 499 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.044309, Avg Loss=0.562521
# Epoch: 500 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.048421, Avg Loss=0.567010
# Epoch: 501 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.041869, Avg Loss=0.561384
# Epoch: 502 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.037104, Avg Loss=0.558142
# Epoch: 503 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.037981, Avg Loss=0.560083
# Epoch: 504 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.044298, Avg Loss=0.561993
# Epoch: 505 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.047676, Avg Loss=0.565491
# Epoch: 506 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.034845, Avg Loss=0.559155
# Epoch: 507 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.036170, Avg Loss=0.558078
# Epoch: 508 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.036912, Avg Loss=0.556978
# Epoch: 509 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.043493, Avg Loss=0.559943
# Epoch: 510 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.041829, Avg Loss=0.562057
# Epoch: 511 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.040464, Avg Loss=0.560518
# Epoch: 512 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.043494, Avg Loss=0.561818
# Epoch: 513 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.036819, Avg Loss=0.560077
# Epoch: 514 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.044131, Avg Loss=0.560279
# Epoch: 515 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.040503, Avg Loss=0.561532
# Epoch: 516 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.032952, Avg Loss=0.559375
# Epoch: 517 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.043080, Avg Loss=0.559248
# Epoch: 518 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.048071, Avg Loss=0.564460
# Epoch: 519 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.037763, Avg Loss=0.559104
# Epoch: 520 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.035275, Avg Loss=0.555166
# Epoch: 521 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.042665, Avg Loss=0.559150
# Epoch: 522 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.038103, Avg Loss=0.558129
# Epoch: 523 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.035272, Avg Loss=0.553069
# Epoch: 524 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.035695, Avg Loss=0.554433
# Epoch: 525 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.038042, Avg Loss=0.555796
# Epoch: 526 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.032851, Avg Loss=0.555854
# Epoch: 527 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.044939, Avg Loss=0.557194
# Epoch: 528 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.036421, Avg Loss=0.557024
# Epoch: 529 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.041564, Avg Loss=0.558874
# Epoch: 530 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.034405, Avg Loss=0.555327
# Epoch: 531 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.039033, Avg Loss=0.555332
# Epoch: 532 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.037518, Avg Loss=0.555688
# Epoch: 533 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.039014, Avg Loss=0.558554
# Epoch: 534 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.054629, Avg Loss=0.562590
# Epoch: 535 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.042238, Avg Loss=0.560261
# Epoch: 536 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.044005, Avg Loss=0.557701
# Epoch: 537 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.050374, Avg Loss=0.563021
# Epoch: 538 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.037223, Avg Loss=0.557696
# Epoch: 539 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.033046, Avg Loss=0.556063
# Epoch: 540 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.042742, Avg Loss=0.558090
# Epoch: 541 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.040303, Avg Loss=0.561665
# Epoch: 542 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.042642, Avg Loss=0.559171
# Epoch: 543 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.046341, Avg Loss=0.559223
# Epoch: 544 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.037333, Avg Loss=0.554785
# Epoch: 545 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.037584, Avg Loss=0.554051
# Epoch: 546 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.051238, Avg Loss=0.560728
# Epoch: 547 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.039694, Avg Loss=0.559403
# Epoch: 548 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.034291, Avg Loss=0.555038
# Epoch: 549 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.042797, Avg Loss=0.553084
# Epoch: 550 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.041074, Avg Loss=0.556078
# Epoch: 551 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.039305, Avg Loss=0.552449
# Epoch: 552 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.035930, Avg Loss=0.555203
# Epoch: 553 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.042414, Avg Loss=0.555392
# Epoch: 554 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.031167, Avg Loss=0.552009
# Epoch: 555 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.039096, Avg Loss=0.550864
# Epoch: 556 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.036984, Avg Loss=0.553630
# Epoch: 557 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.036107, Avg Loss=0.550689
# Epoch: 558 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.036872, Avg Loss=0.554717
# Epoch: 559 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.034560, Avg Loss=0.554226
# Epoch: 560 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.047895, Avg Loss=0.558913
# Epoch: 561 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.039057, Avg Loss=0.553336
# Epoch: 562 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.035596, Avg Loss=0.551215
# Epoch: 563 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.036250, Avg Loss=0.552554
# Epoch: 564 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.034156, Avg Loss=0.551928
# Epoch: 565 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.036403, Avg Loss=0.550938
# Epoch: 566 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.029593, Avg Loss=0.548724
# Epoch: 567 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.048417, Avg Loss=0.553790
# Epoch: 568 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.030261, Avg Loss=0.552111
# Epoch: 569 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.036479, Avg Loss=0.552475
# Epoch: 570 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.041709, Avg Loss=0.553215
# Epoch: 571 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.035872, Avg Loss=0.552362
# Epoch: 572 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.031044, Avg Loss=0.549933
# Epoch: 573 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.036442, Avg Loss=0.551109
# Epoch: 574 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.046385, Avg Loss=0.555387
# Epoch: 575 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.036206, Avg Loss=0.552707
# Epoch: 576 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.031224, Avg Loss=0.547695
# Epoch: 577 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.041104, Avg Loss=0.552040
# Epoch: 578 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.035683, Avg Loss=0.550884
# Epoch: 579 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.041390, Avg Loss=0.550909
# Epoch: 580 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.035400, Avg Loss=0.550204
# Epoch: 581 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.031631, Avg Loss=0.547892
# Epoch: 582 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.037022, Avg Loss=0.550082
# Epoch: 583 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.033854, Avg Loss=0.550466
# Epoch: 584 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.042647, Avg Loss=0.554459
# Epoch: 585 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.037714, Avg Loss=0.550590
# Epoch: 586 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.037935, Avg Loss=0.548776
# Epoch: 587 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.027727, Avg Loss=0.546459
# Epoch: 588 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.034434, Avg Loss=0.547747
# Epoch: 589 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.030379, Avg Loss=0.544251
# Epoch: 590 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.043048, Avg Loss=0.548857
# Epoch: 591 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.033909, Avg Loss=0.548991
# Epoch: 592 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.031314, Avg Loss=0.545319
# Epoch: 593 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.044275, Avg Loss=0.548616
# Epoch: 594 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.055319, Avg Loss=0.554276
# Epoch: 595 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.040594, Avg Loss=0.553472
# Epoch: 596 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.043064, Avg Loss=0.550519
# Epoch: 597 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.048148, Avg Loss=0.558840
# Epoch: 598 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.045155, Avg Loss=0.553715
# Epoch: 599 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.047742, Avg Loss=0.558536
# Epoch: 600 DiscriminatorA Loss= 0.250000,DiscriminatorB Loss= 0.250000, Generator Loss= 0.062669, Avg Loss=0.561830
# C:\ProgramData\Anaconda3\envs\jy3.6\lib\site-packages\ipykernel_launcher.py:212: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\ProgramData\Anaconda3\envs\jy3.6\lib\site-packages\ipykernel_launcher.py:217: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\ProgramData\Anaconda3\envs\jy3.6\lib\site-packages\ipykernel_launcher.py:222: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\ProgramData\Anaconda3\envs\jy3.6\lib\site-packages\ipykernel_launcher.py:229: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\ProgramData\Anaconda3\envs\jy3.6\lib\site-packages\ipykernel_launcher.py:236: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\ProgramData\Anaconda3\envs\jy3.6\lib\site-packages\ipykernel_launcher.py:246: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\ProgramData\Anaconda3\envs\jy3.6\lib\site-packages\ipykernel_launcher.py:253: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
