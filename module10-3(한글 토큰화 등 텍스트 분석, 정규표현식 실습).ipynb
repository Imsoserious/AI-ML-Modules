# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Affinity\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import nltk 
from nltk.tokenize import word_tokenize
print(word_tokenize("Dont't be fooled by the dark sounding name. Mr.Jone's Orphanage is as cheery as cheery goes for a pastry shop"))
# Out:
# ["Dont't", 'be', 'fooled', 'by', 'the', 'dark', 'sounding', 'name', '.', 'Mr.Jone', "'s", 'Orphanage', 'is', 'as', 'cheery', 'as', 'cheery', 'goes', 'for', 'a', 'pastry', 'shop']

# %%
import nltk 
from nltk.tokenize import WordPunctTokenizer
print(WordPunctTokenizer().tokenize("Dont't be fooled by the dark sounding name. Mr.Jone's Orphanage is as cheery as cheery goes for a pastry shop"))
# Out:
# ['Dont', "'", 't', 'be', 'fooled', 'by', 'the', 'dark', 'sounding', 'name', '.', 'Mr', '.', 'Jone', "'", 's', 'Orphanage', 'is', 'as', 'cheery', 'as', 'cheery', 'goes', 'for', 'a', 'pastry', 'shop']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()
text = "Starting a home-based restaurant may be an ideal. It doesn't have a food chain or restaurant of their own"
tokenizer.tokenize(text)
# Out:
# ['Starting',
#  'a',
#  'home-based',
#  'restaurant',
#  'may',
#  'be',
#  'an',
#  'ideal.',
#  'It',
#  'does',
#  "n't",
#  'have',
#  'a',
#  'food',
#  'chain',
#  'or',
#  'restaurant',
#  'of',
#  'their',
#  'own']

# %%
import nltk 
from nltk.tokenize import word_tokenize
text ="I am activiely locking for Ph.D students. and you are a Ph.D. student."
print(word_tokenize(text))
# Out:
# ['I', 'am', 'activiely', 'locking', 'for', 'Ph.D', 'students', '.', 'and', 'you', 'are', 'a', 'Ph.D.', 'student', '.']

# %%
nltk.download('averaged_perceptron_tagger')
from nltk.tag import pos_tag
x = word_tokenize(text)
pos_tag(x)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Affinity\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [('I', 'PRP'),
#  ('am', 'VBP'),
#  ('activiely', 'RB'),
#  ('locking', 'VBG'),
#  ('for', 'IN'),
#  ('Ph.D', 'NNP'),
#  ('students', 'NNS'),
#  ('.', '.'),
#  ('and', 'CC'),
#  ('you', 'PRP'),
#  ('are', 'VBP'),
#  ('a', 'DT'),
#  ('Ph.D.', 'NNP'),
#  ('student', 'NN'),
#  ('.', '.')]

# %%
from konlpy.tag import Okt
okt = Okt()
print(okt.morphs("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
# Out:
# C:\ProgramData\Anaconda3\envs\jy3.6\lib\site-packages\jpype\_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)
# ['열심히', '코딩', '한', '당신', ',', '연휴', '에는', '여행', '을', '가봐요']

# %%
print(okt.pos("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
# Out:
# [('열심히', 'Adverb'), ('코딩', 'Noun'), ('한', 'Josa'), ('당신', 'Noun'), (',', 'Punctuation'), ('연휴', 'Noun'), ('에는', 'Josa'), ('여행', 'Noun'), ('을', 'Josa'), ('가봐요', 'Verb')]

# %%
print(okt.nouns("열심히 코딩한 당신, 연휴에는 여행을 가봐요"))
# Out:
# ['코딩', '당신', '연휴', '여행']

# %%
# 한나눔 분석이 사용 예제
from konlpy.tag import Hannanum
han = Hannanum()
print(han.nouns("형태소 분석을 해봅시다. 어렵지않아요"))
# Out:
# ['형태소', '분석']

# %%
print(han.morphs("형태소 분석을 해봅시다. 어렵지않아요"))
# okt보다 문법적으로 더 자세하게 분석함( ex: ''ㅂ시다')
# Out:
# ['형태소', '분석', '을', '하', '어', '보', 'ㅂ시다', '.', '어렵', '지', '않', '아요']

# %%
print(han.pos("형태소 분석을 해봅시다. 어렵지않아요"))
# Out:
# [('형태소', 'N'), ('분석', 'N'), ('을', 'J'), ('하', 'P'), ('어', 'E'), ('보', 'P'), ('ㅂ시다', 'E'), ('.', 'S'), ('어렵', 'P'), ('지', 'E'), ('않', 'P'), ('아요', 'E')]

# %%
from konlpy.tag import Hannanum
han = Hannanum()
text = input("분석할 텍스트를 입력하세요: ")
result = han.pos(text)
for lex, pos in result:
    print("{}\t{}".format(lex,pos))
# Out:
# 분석할 텍스트를 입력하세요: korean do
# korean	F
# do	F

# %%
from konlpy.tag import Okt
okt = Okt()
text = input("분석할 텍스트를 입력하세요: ")
result = okt.pos(text)
for lex, pos in result:
    print("{}\t{}".format(lex,pos))
# okt가 띄어쓰기 안된 부분도 구분을 잘 함.
# Out:
# 분석할 텍스트를 입력하세요: korean do
# korean	Alpha
# do	Alpha

# %%
nltk.download('stopwords')
import nltk
from nltk.corpus import stopwords
stopwords.words('english')[:10]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Affinity\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
# 영어 불용어 제거 실습
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

example = "Family is not an important thing. It's everything"
stop_words = set(stopwords.words('english'))

word_tokens = word_tokenize(example)
result=[]

for w in word_tokens:
    if w not in stop_words:
        result.append(w)
        
print(word_tokens)
print(result)
# Out:
# ['Family', 'is', 'not', 'an', 'important', 'thing', '.', 'It', "'s", 'everything']
# ['Family', 'important', 'thing', '.', 'It', "'s", 'everything']

# %%
# 한글 불용어 제거 실습
# 직접 불용어를 정의한 후에 진행
example = "고기를 아무렇게나 구우려고 하면 안 돼. 고기라고 다 같은 게 아니거든. 예컨대 삼겹살을 구울 때는 중요한 게 있지"
# 불용어 정의
stop_words= "아무아무렇게나아니거든있지안게 ."
#stop_words = stop_words.split(' ')

word_tokens = word_tokenize(example)
result = []

for w in word_tokens:
    if w not in stop_words:
        result.append(w)

print(word_tokens)
print(result)
# Out:
# ['고기를', '아무렇게나', '구우려고', '하면', '안', '돼', '.', '고기라고', '다', '같은', '게', '아니거든', '.', '예컨대', '삼겹살을', '구울', '때는', '중요한', '게', '있지']
# ['고기를', '구우려고', '하면', '돼', '고기라고', '다', '같은', '예컨대', '삼겹살을', '구울', '때는', '중요한']

# %%
import nltk
from konlpy.corpus import kobill # konlpy에 내장된 법률안 읽어오기

files_ko = kobill.fileids()
files_ko
# Out:
# ['1809890.txt',
#  '1809891.txt',
#  '1809892.txt',
#  '1809893.txt',
#  '1809894.txt',
#  '1809895.txt',
#  '1809896.txt',
#  '1809897.txt',
#  '1809898.txt',
#  '1809899.txt']

# %%
doc_ko = kobill.open('1809890.txt').read()
doc_ko
# Out:
# '지방공무원법 일부개정법률안\n\n(정의화의원 대표발의 )\n\n 의 안\n 번 호\n\n9890\n\n발의연월일 : 2010.  11.  12.  \n\n발  의  자 : 정의화․이명수․김을동 \n\n이사철․여상규․안규백\n\n황영철․박영아․김정훈\n\n김학송 의원(10인)\n\n제안이유 및 주요내용\n\n  초등학교 저학년의 경우에도 부모의 따뜻한 사랑과 보살핌이 필요\n\n한 나이이나, 현재 공무원이 자녀를 양육하기 위하여 육아휴직을 할 \n\n수 있는 자녀의 나이는 만 6세 이하로 되어 있어 초등학교 저학년인 \n\n자녀를 돌보기 위해서는 해당 부모님은 일자리를 그만 두어야 하고 \n\n이는 곧 출산의욕을 저하시키는 문제로 이어질 수 있을 것임.\n\n  따라서 육아휴직이 가능한 자녀의 연령을 만 8세 이하로 개정하려\n\n는 것임(안 제63조제2항제4호).\n\n- 1 -\n\n\x0c법률  제        호\n\n지방공무원법 일부개정법률안\n\n지방공무원법 일부를 다음과 같이 개정한다.\n\n제63조제2항제4호 중 “만 6세 이하의 초등학교 취학 전 자녀를”을 “만 \n\n8세 이하(취학 중인 경우에는 초등학교 2학년 이하를 말한다)의 자녀를”\n\n로 한다.\n\n부      칙\n\n이 법은 공포한 날부터 시행한다.\n\n- 3 -\n\n\x0c신 ·구조문대비표\n\n현      행\n\n개   정   안\n\n제63조(휴직) ① (생  략)\n\n제63조(휴직) ① (현행과 같음)\n\n  ② 공무원이 다음 각 호의 어\n\n  ② -------------------------\n\n느 하나에 해당하는 사유로 휴\n\n----------------------------\n\n직을 원하면 임용권자는 휴직\n\n----------------------------\n\n을 명할 수 있다. 다만, 제4호\n\n-------------.---------------\n\n의 경우에는 대통령령으로 정\n\n-------------------------
# ...

# %%
from konlpy.tag import Okt
okt = Okt()

nouns = okt.nouns(doc_ko)
nouns
# Out:
# C:\ProgramData\Anaconda3\envs\jy3.6\lib\site-packages\jpype\_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)
# ['지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '안',
#  '정의화',
#  '의원',
#  '대표',
#  '발의',
#  '의',
#  '안',
#  '번',
#  '호',
#  '발의',
#  '연월일',
#  '발',
#  '의',
#  '자',
#  '정의화',
#  '이명수',
#  '김을동',
#  '이사철',
#  '여상규',
#  '안규백',
#  '황영철',
#  '박영아',
#  '김정훈',
#  '김학송',
#  '의원',
#  '인',
#  '제안',
#  '이유',
#  '및',
#  '내용',
#  '초등학교',
#  '저학년',
#  '경우',
#  '부모',
#  '사랑',
# ...

# %%
ko = nltk.Text(nouns, name = '의안 제1809894호')
print(len(ko.tokens))
print(len(set(ko.tokens)))
ko.vocab()
# Out:
# 735
# 250
# FreqDist({'육아휴직': 38, '발생': 19, '만': 18, '이하': 18, '비용': 17, '액': 17, '경우': 16, '세': 16, '자녀': 14, '고용': 14, ...})

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import platform
path = 'c:/Windows/Fonts/malgun.ttf'
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname=path).get_name()
rc('font', family = font_name)

plt.figure(figsize=(12,6))
ko.plot(50)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS

stopwords = ['정','제','및','안','자','과','수','의','이','발','만','액','호','월','위','세','중','표','명','것','해당','이상','생','략']
ko = [each_word for each_word in ko if each_word not in stopwords]
ko
# Out:
# ['지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '정의화',
#  '의원',
#  '대표',
#  '발의',
#  '번',
#  '발의',
#  '연월일',
#  '정의화',
#  '이명수',
#  '김을동',
#  '이사철',
#  '여상규',
#  '안규백',
#  '황영철',
#  '박영아',
#  '김정훈',
#  '김학송',
#  '의원',
#  '인',
#  '제안',
#  '이유',
#  '내용',
#  '초등학교',
#  '저학년',
#  '경우',
#  '부모',
#  '사랑',
#  '필요',
#  '나이',
#  '현재',
#  '공무원',
#  '자녀',
#  '양육',
#  '육아휴직',
#  '자녀',
#  '나이',
#  '이하',
#  '초등학교',
#  '저학년',
#  '자녀',
#  '부모님',
#  '일자리',
#  '곧',
#  '출산',
#  '의욕',
#  '저하',
#  '문제',
#  '것임',
#  '따라서',
#  '육아휴직',
#  '자녀',
#  '연령',
#  '이하',
#  '개정',
#  '것임',
#  '항제',
#  '법률',
#  '지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '지방공무원법',
#  '일부',
#  '다음',
#  '개정',
#  '항제',
#  '이하',
#  '초등학교',
#  '취학',
#  '전',
#  '자녀',
#  '이하',
#  '취학',
#  '중인',
#  '경우',
#  '초등학교',
#  '학년',
#  '이하',
#  '말',
#  '자녀',
#  '로',
#  '부',
#  '칙',
#  '법',
#  '공포',
#  '날',
#  '시행',
#  '신',
#  '구조',
#  '문대비',
#  '현',
#  '행',
#  '개',
#  '휴직',
#  '휴직',
#  '현행',
#  '공무원',
#  '다음',
#  '각',
#  '호의',
#  '느',
#  '하나',
#  '사유',
#  '직',
# ...

# %%
ko = nltk.Text(ko, name = '의안 제1809894호')

plt.figure(figsize=(12,6))
ko.plot(50)
plt.show()

# %%
data = ko.vocab().most_common(30)

wordcloud = WordCloud(font_path = 'c:/Windows/Fonts/malgun.ttf',
                     background_color = 'white').generate_from_frequencies(dict(data))
plt.figure(figsize=(12,6))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
import re
r = re.compile("ab{2,5}c")
r.search("abbbbbc")
# Out:
# <_sre.SRE_Match object; span=(0, 7), match='abbbbbc'>

# %%
r = re.compile("[a-z]")
r.search("BBBaB")
# Out:
# <_sre.SRE_Match object; span=(3, 4), match='a'>

# %%
r = re.compile("[^abc]")
r.search("abcd")
# Out:
# <_sre.SRE_Match object; span=(3, 4), match='d'>

# %%
text = """이름: 김진영
전화번호: 010 - 2726 - 9348
나이: 28
성별: 남"""
# \d+: +는 숫자가 여러개 나와도 상관 없다는 의미
re.findall("\d+",text)
# Out:
# ['010', '2726', '9348', '28']

# %%
# 특수문자 제거

text = """name: jinyoung kim
phone number: 010 - 2726 - 9348
age: 28
sex: male"""
re.sub("[^a-z0-9]",' ',text)
# Out:
# 'name  jinyoung kim phone number  010   2726   9348 age  28 sex  male'

# %%
# 길이가 1~2인 단어들 제거
text = "i was wondering if anyone out there could enlighten me on this car"
shortword = re.compile(r'\\*\b\w{1,2}\b') # r은 역슬래시를 표현하기 위한 것. \b는 경계를 나타냄
print(shortword.sub('',text))
# Out:
#  was wondering  anyone out there could enlighten   this car

# %% [markdown]
# ### 정규표현식 연습문제

# %%
# 1번 문제: 정규표현식으로 번호 추출하기
import re
text = "제 휴대폰 번호는 010-1234-5678이고, 전화 번호는 0211334477입니다."
reg = re.compile("\d{2,3}-?\d{4}-?\d{4}")
result = reg.findall(text)

#string = re.sub("[^\d]",' ',text)
#string_list=string.split('  ')
#phone_number = [x.replace(" ","") for x in string_list if x]
#for i in range(len(phone_number)):
#    phone_number[i]= phone_number[i][:-8] + re.sub("[\d+]","*",phone_number[i][-8:])
result
# Out:
# ['010-1234-5678', '0211334477']

# %%
# 2번 문제: 정규표현식으로 번호 추출하기
import re
text = "제 휴대폰 번호는 010-1234-5678이고, 전화 번호는 0211334477과 02.1133.5599입니다."
reg = re.compile("\d{2,3}\W?\d{4}\W?\d{4}")
result = reg.findall(text)
#string = re.sub("[^\d]",' ',text)
#string_list=string.split('  ')


#phone_number = [x.replace(" ","") for x in string_list if x]

#for i in range(len(phone_number)):
#    phone_number[i]= phone_number[i][:-8] + re.sub("[\d+]","*",phone_number[i][-8:])
#phone_number
result
# Out:
# ['010-1234-5678', '0211334477', '02.1133.5599']

# %%
import re
text = "제 휴대폰 번호는 010-1234-5678이고, 전화 번호는 0211334477입니다."
#reg = re.compile("\d{2,3}-?\d{4}-?\d{4}")
result = re.sub("\d{2,3}-?\d{4}-?\d{4}"," *** ",text)
print(result)
# Out:
# 제 휴대폰 번호는  *** 이고, 전화 번호는  *** 입니다.

# %%
import re
text = "제 휴대폰 번호는 010-1234-5678이고, 전화 번호는 0211334477과 02.1133.5599입니다."
result = re.sub("\d+"," *** ",text)
print(result)
# Out:
# 제 휴대폰 번호는  *** - *** - *** 이고, 전화 번호는  *** 과  *** . *** . *** 입니다.
